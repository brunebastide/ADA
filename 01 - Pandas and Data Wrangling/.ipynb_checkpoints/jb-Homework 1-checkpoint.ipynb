# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = './Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
# Write your answer here
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn.apionly as sns
import matplotlib.pyplot as plt

sns.set_style("dark")
# Out:
# /usr/local/lib/python3.6/site-packages/seaborn/apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
def files_for_country(c):
    pattern = '{}/ebola/{}_data/*.csv'.format(DATA_FOLDER, c)
    return glob.glob(pattern)


def row_description_file_analysis(df, data_field='Description', file_field='File'):
    df = df.copy()
    df = df[[data_field, file_field]]
    df['Count'] = 1
    pivot = df.pivot(index=data_field, columns=file_field, values='Count')
    pivot.fillna(value=0.0, inplace=True)
    return pivot
    
    
def scatter_plot_pivot(pivot, radius=40):
    """Plot a grid for columns and index of a DF with point proportional to the value"""
    n_row = len(pivot.index)
    n_col = len(pivot.columns)
    range_row = np.arange(0, n_row)
    range_col = np.arange(0, n_col)
    xs, ys = np.meshgrid(range_col, range_row, sparse=False, indexing='ij')
    fig, ax = plt.subplots(figsize=(int(n_col/4),int(n_row / 5)))
    ax.scatter(xs.ravel(), ys.ravel(), s=np.transpose(pivot.values).ravel() * radius)
    ax.set_xticklabels(pivot.columns)
    ax.xaxis.tick_top()
    plt.xticks(range_col, rotation=90)
    plt.yticks(range_row)
    ax.set_yticklabels(pivot.index)
    plt.show()


def import_df(country, with_file=True, date_fields=['Date']):
    """Parse and concat all the files for a country"""
    files = files_for_country(country)
    dfs = []
    for f in files:
        df = pd.read_csv(f, parse_dates=date_fields)
        if with_file:
            df['File'] = f
        dfs.append(df)

    df_full = pd.concat(dfs)
    df_full = df_full.fillna(0)
    df_full['Country'] = country
    return df_full

def split_year_month(df, date_field='Date'):
    """Add Year and Month column to the DF extracted from a date column"""
    df['Year'] = df[date_field].apply(lambda d: d.year)
    df['Month'] = df[date_field].apply(lambda d: d.month)

# %% [markdown]
# ### Guinea

# %%
guinea = import_df('guinea')
guinea = guinea[['Date', 'Description', 'Country', 'Totals', 'File']]
guinea
# Out:
#          Date                                      Description Country Totals  \
# 0  2014-08-04                            New cases of suspects  guinea      5
# 1  2014-08-04                           New cases of probables  guinea      0
# 2  2014-08-04                           New cases of confirmed  guinea      4
# 3  2014-08-04                Total new cases registered so far  guinea      9
# 4  2014-08-04                          Total cases of suspects  guinea     11
# 5  2014-08-04                         Total cases of probables  guinea    133
# 6  2014-08-04                         Total cases of confirmed  guinea    351
# 7  2014-08-04     Cumulative (confirmed + probable + suspects)  guinea    495
# 8  2014-08-04                      New deaths registered today  guinea      2
# 9  2014-08-04          New deaths registered today (confirmed)  guinea      2
# 10 2014-08-04          New deaths registered today (probables)  guinea      0
# 11 2014-08-04           New deaths registered today (suspects)  guinea      0
# 12 2014-08-04                         Total deaths of suspects  guinea      2
# 13 2014-08-04                        Total deaths of probables  guinea    133
# 14 2014-08-04                        Total deaths of confirmed  guinea    228
# 15 2014-08-04  Total deaths (confirmed + probables + suspects)  guinea    363
# 16 2014-08-04                           Total PEC center today  guinea     31
# 17 2014-08-04               Total PEC center today (confirmed)  guinea     18
# 18 2014-08-04               Total PEC center today (probables)  guinea      0
# 19 2014-08-04                Total PEC center today (suspects)  guinea     13
# 20 2014-08-04        Total of deaths in confirmed cases in CTE  guinea    138
# 21 2014-08-04         Total of cured in confirmed cases in CTE  guinea     89
# 22 2014-08-04                   Number of male confirmed cases  guinea    161
# 23 2014-08-04                 Number of female confirmed cases  guinea    190
# 24 2014-08-04                   Number of male probables cases  guinea     52
# 25 2014-08-04                 Number of female probables cases  guinea     81
# 26 2014-08-04                    Number of male suspects cases  guinea      7
# 27 2014-08-04                  Number of female suspects cases  guinea      6
# 28 2014-08-04                       Total number of male cases  guinea    220
# 29 2014-08-04                     Total number of female cases  guinea    277
# ..        ...                                              ...     ...    ...
# 2  2014-10-01                           New cases of confirmed  guinea      6
# 3  2014-10-01                Total new cases registered so far  guinea     34
# 4  2014-10-01                          Total cases of suspects  guinea     45
# 5  2014-10-01                         Total cases of probables  guinea    177
# 6  2014-10-01                         Total cases of confirmed  guinea    977
# 7  2014-10-01     Cumulative (confirmed + probable + suspects)  guinea   1199
# 8  2014-10-01                  Total suspected non-class cases  guinea    974
# 9  2014-10-01                            New deaths registered  guinea     15
# 10 2014-10-01                         Total deaths of suspects  guinea      0
# 11 2014-10-01                        Total deaths of probables  guinea    177
# 12 2014-10-01                        Total deaths of confirmed  guinea    562
# 13 2014-10-01  Total deaths (confirmed + probables + suspects)  guinea    739
# 14 2014-10-01        Fatality rate for confirmed and probables  guinea    62%
# 15 2014-10-01      New cases of confirmed among health workers  guinea      2
# 16 2014-10-01     Total case of confirmed among health workers  guinea     69
# 17 2014-10-01       New deaths registered among health workers  guinea      0
# 18 2014-10-01     Total deaths registered among health workers  guinea     35
# 19 2014-10-01                         New admits to CTE so far  guinea     25
# 20 2014-10-01        Total number of hospitalized cases in CTE  guinea    114
# 21 2014-10-01                   Total number of exits from CTE  guinea     29
# 22 2014-10-01                Total number of admissions to CTE  guinea   1576
# 23 2014-10-01                   New contacts registered so far  guinea      0
# 24 2014-10-01        Total contacts registered from start date  guinea  11772
# 25 2014-10-01               Number of contacts to follow today  guinea   2661
# 26 2014-10-01                Number of contacts followed today  guinea   2595
# 27 2014-10-01      Number of contacts out of the track 21 days  guinea   9110
# 28 2014-10-01             Number of contacts lost to follow up  guinea      1
# 29 2014-10-01                Number of samples collected today  guinea     25
# 30 2014-10-01                     Number of samples under test  guinea      0
# 31 2014-10-01                             Total samples tested  guinea   2832
#
#                                        File
# 0   ./Data/ebola/guinea_data/2014-08-04.csv
# 1   ./Data/ebola/guinea_data/2014-08-04.csv
# 2   ./Data/ebola/guinea_data/2014-08-04.csv
# 3   ./Data/ebola/guinea_data/2014-08-04.csv
# 4   ./Data/ebola/guinea_data/2014-08-04.csv
# 5   ./Data/ebola/guinea_data/2014-08-04.csv
# 6   ./Data/ebola/guinea_data/2014-08-04.csv
# 7   ./Data/ebola/guinea_data/2014-08-04.csv
# 8   ./Data/ebola/guinea_data/2014-08-04.csv
# 9   ./Data/ebola/guinea_data/2014-08-04.csv
# 10  ./Data/ebola/guinea_data/2014-08-04.csv
# 11  ./Data/ebola/guinea_data/2014-08-04.csv
# 12  ./Data/ebola/guinea_data/2014-08-04.csv
# 13  ./Data/ebola/guinea_data/2014-08-04.csv
# 14  ./Data/ebola/guinea_data/2014-08-04.csv
# 15  ./Data/ebola/guinea_data/2014-08-04.csv
# 16  ./Data/ebola/guinea_data/2014-08-04.csv
# 17  ./Data/ebola/guinea_data/2014-08-04.csv
# 18  ./Data/ebola/guinea_data/2014-08-04.csv
# 19  ./Data/ebola/guinea_data/2014-08-04.csv
# 20  ./Data/ebola/guinea_data/2014-08-04.csv
# 21  ./Data/ebola/guinea_data/2014-08-04.csv
# 22  ./Data/ebola/guinea_data/2014-08-04.csv
# 23  ./Data/ebola/guinea_data/2014-08-04.csv
# 24  ./Data/ebola/guinea_data/2014-08-04.csv
# 25  ./Data/ebola/guinea_data/2014-08-04.csv
# 26  ./Data/ebola/guinea_data/2014-08-04.csv
# 27  ./Data/ebola/guinea_data/2014-08-04.csv
# 28  ./Data/ebola/guinea_data/2014-08-04.csv
# 29  ./Data/ebola/guinea_data/2014-08-04.csv
# ..                                      ...
# 2   ./Data/ebola/guinea_data/2014-10-01.csv
# 3   ./Data/ebola/guinea_data/2014-10-01.csv
# 4   ./Data/ebola/guinea_data/2014-10-01.csv
# 5   ./Data/ebola/guinea_data/2014-10-01.csv
# 6   ./Data/ebola/guinea_data/2014-10-01.csv
# 7   ./Data/ebola/guinea_data/2014-10-01.csv
# 8   ./Data/ebola/guinea_data/2014-10-01.csv
# 9   ./Data/ebola/guinea_data/2014-10-01.csv
# 10  ./Data/ebola/guinea_data/2014-10-01.csv
# 11  ./Data/ebola/guinea_data/2014-10-01.csv
# 12  ./Data/ebola/guinea_data/2014-10-01.csv
# 13  ./Data/ebola/guinea_data/2014-10-01.csv
# 14  ./Data/ebola/guinea_data/2014-10-01.csv
# 15  ./Data/ebola/guinea_data/2014-10-01.csv
# 16  ./Data/ebola/guinea_data/2014-10-01.csv
# 17  ./Data/ebola/guinea_data/2014-10-01.csv
# 18  ./Data/ebola/guinea_data/2014-10-01.csv
# 19  ./Data/ebola/guinea_data/2014-10-01.csv
# 20  ./Data/ebola/guinea_data/2014-10-01.csv
# 21  ./Data/ebola/guinea_data/2014-10-01.csv
# 22  ./Data/ebola/guinea_data/2014-10-01.csv
# 23  ./Data/ebola/guinea_data/2014-10-01.csv
# 24  ./Data/ebola/guinea_data/2014-10-01.csv
# 25  ./Data/ebola/guinea_data/2014-10-01.csv
# 26  ./Data/ebola/guinea_data/2014-10-01.csv
# 27  ./Data/ebola/guinea_data/2014-10-01.csv
# 28  ./Data/ebola/guinea_data/2014-10-01.csv
# 29  ./Data/ebola/guinea_data/2014-10-01.csv
# 30  ./Data/ebola/guinea_data/2014-10-01.csv
# 31  ./Data/ebola/guinea_data/2014-10-01.csv
#
# [714 rows x 5 columns]

# %%
# Analysis of the rows in each CSV file
piv = row_description_file_analysis(guinea)
scatter_plot_pivot(piv)

# %%
# TODO check fields that we take into account
guinea_new_desc = ['Total new cases registered so far']
guinea_death_desc = ['New deaths registered', 'New deaths registered today']

# Unify the Description field
guinea_new_df = guinea.query('Description in @guinea_new_desc').copy()
guinea_new_df.loc[:,'Description'] = 'New case'
guinea_death_df = guinea.query('Description in @guinea_death_desc').copy()
guinea_death_df.loc[:,'Description'] = 'Death'

guinea_filtered = pd.concat([guinea_new_df, guinea_death_df])

split_year_month(guinea_filtered)
guinea_filtered.Totals = pd.to_numeric(guinea_filtered.Totals)
guinea_filtered.groupby(['Country', 'Description', 'Year', 'Month']).sum()
# Out:
#                                 Totals
# Country Description Year Month
# guinea  Death       2014 8          17
#                          9          57
#                          10         15
#         New case    2014 8         129
#                          9         314
#                          10         34

# %% [markdown]
# ### Liberia

# %%
liberia = import_df('liberia')
liberia = liberia[['Date', 'Variable', 'Country', 'National', 'File']]
liberia
# Out:
#          Date                                           Variable  Country  \
# 0  2014-06-16                                Specimens collected  liberia
# 1  2014-06-16                      Specimens pending for testing  liberia
# 2  2014-06-16                             Total specimens tested  liberia
# 3  2014-06-16                              Newly reported deaths  liberia
# 4  2014-06-16                   Total death/s in confirmed cases  liberia
# 5  2014-06-16                    Total death/s in probable cases  liberia
# 6  2014-06-16                   Total death/s in suspected cases  liberia
# 7  2014-06-16  Total death/s in confirmed, probable, suspecte...  liberia
# 8  2014-06-16  Case Fatality Rate (CFR) - Confirmed & Probabl...  liberia
# 9  2014-06-16                            Newly reported contacts  liberia
# 10 2014-06-16                              Total contacts listed  liberia
# 11 2014-06-16                          Currently under follow-up  liberia
# 12 2014-06-16                                      Contacts seen  liberia
# 13 2014-06-16            Contacts who completed 21 day follow-up  liberia
# 14 2014-06-16                         Contacts lost to follow-up  liberia
# 15 2014-06-16                                     New admissions  liberia
# 16 2014-06-16             Total no. currently in Treatment Units  liberia
# 17 2014-06-16                                   Total discharges  liberia
# 18 2014-06-16                     Cumulative admission/isolation  liberia
# 19 2014-06-16                        Newly Reported Cases in HCW  liberia
# 20 2014-06-16                         Cumulative cases among HCW  liberia
# 21 2014-06-16                       Newly Reported deaths in HCW  liberia
# 22 2014-06-16                        Cumulative deaths among HCW  liberia
# 23 2014-06-16                             New Case/s (Suspected)  liberia
# 24 2014-06-16                              New Case/s (Probable)  liberia
# 25 2014-06-16                             New case/s (confirmed)  liberia
# 26 2014-06-16                              Total suspected cases  liberia
# 27 2014-06-16                               Total probable cases  liberia
# 28 2014-06-16                              Total confirmed cases  liberia
# 29 2014-06-16  Total Number of Confirmed Cases of Sierra Leon...  liberia
# ..        ...                                                ...      ...
# 2  2014-12-09                             Total specimens tested  liberia
# 3  2014-12-09                              Newly reported deaths  liberia
# 4  2014-12-09                   Total death/s in confirmed cases  liberia
# 5  2014-12-09                    Total death/s in probable cases  liberia
# 6  2014-12-09                   Total death/s in suspected cases  liberia
# 7  2014-12-09  Total death/s in confirmed, \n probable, suspe...  liberia
# 8  2014-12-09  Case Fatality Rate (CFR) - \n Confirmed & Prob...  liberia
# 9  2014-12-09                            Newly reported contacts  liberia
# 10 2014-12-09                              Total contacts listed  liberia
# 11 2014-12-09                          Currently under follow-up  liberia
# 12 2014-12-09                                      Contacts seen  liberia
# 13 2014-12-09         Contacts who completed 21 day \n follow-up  liberia
# 14 2014-12-09                         Contacts lost to follow-up  liberia
# 15 2014-12-09                                     New admissions  liberia
# 16 2014-12-09          Total no. currently in Treatment \n Units  liberia
# 17 2014-12-09                                   Total discharges  liberia
# 18 2014-12-09                     Cumulative admission/isolation  liberia
# 19 2014-12-09                        Newly Reported Cases in HCW  liberia
# 20 2014-12-09                         Cumulative cases among HCW  liberia
# 21 2014-12-09                       Newly Reported deaths in HCW  liberia
# 22 2014-12-09                        Cumulative deaths among HCW  liberia
# 23 2014-12-09                             New Case/s (Suspected)  liberia
# 24 2014-12-09                              New Case/s (Probable)  liberia
# 25 2014-12-09                             New case/s (confirmed)  liberia
# 26 2014-12-09                              Total suspected cases  liberia
# 27 2014-12-09                               Total probable cases  liberia
# 28 2014-12-09                              Total confirmed cases  liberia
# 29 2014-12-09  Total Number of Confirmed Cases \n of Sierra L...  liberia
# 30 2014-12-09  Total Number of Confirmed Cases \n of Guinean ...  liberia
# 31 2014-12-09  Cumulative confirmed, probable and suspected c...  liberia
#
#     National                                      File
# 0        1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 1        0.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 2       28.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 3        2.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 4        8.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 5        6.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 6        2.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 7       16.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 8        0.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 9       41.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 10     108.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 11      95.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 12      95.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 13      11.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 14       0.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 15       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 16       5.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 17       3.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 18       5.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 19       0.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 20       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 21       0.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 22       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 23       2.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 24       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 25       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 26       4.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 27       6.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 28      12.0  ./Data/ebola/liberia_data/2014-06-16.csv
# 29       1.0  ./Data/ebola/liberia_data/2014-06-16.csv
# ..       ...                                       ...
# 2        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 3        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 4        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 5        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 6        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 7     3290.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 8        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 9        0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 10       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 11       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 12       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 13       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 14       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 15       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 16       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 17       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 18       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 19       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 20       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 21       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 22       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 23    3050.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 24    1801.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 25    2946.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 26       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 27       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 28       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 29       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 30       0.0  ./Data/ebola/liberia_data/2014-12-09.csv
# 31    7797.0  ./Data/ebola/liberia_data/2014-12-09.csv
#
# [3152 rows x 5 columns]

# %%
# Analysis of the rows in each CSV file
piv = row_description_file_analysis(liberia)
scatter_plot_pivot(piv, data_field='Variable')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-edee9085c2b0> in <module>()
#       1 # Analysis of the rows in each CSV file
# ----> 2 piv = row_description_file_analysis(liberia)
#       3 scatter_plot_pivot(piv, data_field='Variable')
#
# <ipython-input-15-b63587239748> in row_description_file_analysis(df, data_field, file_field)
#       6 def row_description_file_analysis(df, data_field='Description', file_field='File'):
#       7     df = df.copy()
# ----> 8     df = df[[data_field, file_field]]
#       9     df['Count'] = 1
#      10     pivot = df.pivot(index=data_field, columns=file_field, values='Count')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Description'] not in index"

# %%
files = files_for_country('liberia')
dfs = []
for f in files:
    df = pd.read_csv(f, parse_dates=['Date'])
    df['File'] = f
    dfs.append(df)
liberia = pd.concat(dfs)
liberia = liberia[['Date', 'Variable', 'National', 'File']]
liberia.columns = ['Date', 'Description', 'Totals', 'File']
liberia = liberia.fillna(0)
liberia['Country'] = 'Liberia'

liberia
# Out:
#          Date                                        Description  Totals  \
# 0  2014-06-16                                Specimens collected     1.0
# 1  2014-06-16                      Specimens pending for testing     0.0
# 2  2014-06-16                             Total specimens tested    28.0
# 3  2014-06-16                              Newly reported deaths     2.0
# 4  2014-06-16                   Total death/s in confirmed cases     8.0
# 5  2014-06-16                    Total death/s in probable cases     6.0
# 6  2014-06-16                   Total death/s in suspected cases     2.0
# 7  2014-06-16  Total death/s in confirmed, probable, suspecte...    16.0
# 8  2014-06-16  Case Fatality Rate (CFR) - Confirmed & Probabl...     0.0
# 9  2014-06-16                            Newly reported contacts    41.0
# 10 2014-06-16                              Total contacts listed   108.0
# 11 2014-06-16                          Currently under follow-up    95.0
# 12 2014-06-16                                      Contacts seen    95.0
# 13 2014-06-16            Contacts who completed 21 day follow-up    11.0
# 14 2014-06-16                         Contacts lost to follow-up     0.0
# 15 2014-06-16                                     New admissions     1.0
# 16 2014-06-16             Total no. currently in Treatment Units     5.0
# 17 2014-06-16                                   Total discharges     3.0
# 18 2014-06-16                     Cumulative admission/isolation     5.0
# 19 2014-06-16                        Newly Reported Cases in HCW     0.0
# 20 2014-06-16                         Cumulative cases among HCW     1.0
# 21 2014-06-16                       Newly Reported deaths in HCW     0.0
# 22 2014-06-16                        Cumulative deaths among HCW     1.0
# 23 2014-06-16                             New Case/s (Suspected)     2.0
# 24 2014-06-16                              New Case/s (Probable)     1.0
# 25 2014-06-16                             New case/s (confirmed)     1.0
# 26 2014-06-16                              Total suspected cases     4.0
# 27 2014-06-16                               Total probable cases     6.0
# 28 2014-06-16                              Total confirmed cases    12.0
# 29 2014-06-16  Total Number of Confirmed Cases of Sierra Leon...     1.0
# ..        ...                                                ...     ...
# 2  2014-12-09                             Total specimens tested     0.0
# 3  2014-12-09                              Newly reported deaths     0.0
# 4  2014-12-09                   Total death/s in confirmed cases     0.0
# 5  2014-12-09                    Total death/s in probable cases     0.0
# 6  2014-12-09                   Total death/s in suspected cases     0.0
# 7  2014-12-09  Total death/s in confirmed, \n probable, suspe...  3290.0
# 8  2014-12-09  Case Fatality Rate (CFR) - \n Confirmed & Prob...     0.0
# 9  2014-12-09                            Newly reported contacts     0.0
# 10 2014-12-09                              Total contacts listed     0.0
# 11 2014-12-09                          Currently under follow-up     0.0
# 12 2014-12-09                                      Contacts seen     0.0
# 13 2014-12-09         Contacts who completed 21 day \n follow-up     0.0
# 14 2014-12-09                         Contacts lost to follow-up     0.0
# 15 2014-12-09                                     New admissions     0.0
# 16 2014-12-09          Total no. currently in Treatment \n Units     0.0
# 17 2014-12-09                                   Total discharges     0.0
# 18 2014-12-09                     Cumulative admission/isolation     0.0
# 19 2014-12-09                        Newly Reported Cases in HCW     0.0
# 20 2014-12-09                         Cumulative cases among HCW     0.0
# 21 2014-12-09                       Newly Reported deaths in HCW     0.0
# 22 2014-12-09                        Cumulative deaths among HCW     0.0
# 23 2014-12-09                             New Case/s (Suspected)  3050.0
# 24 2014-12-09                              New Case/s (Probable)  1801.0
# 25 2014-12-09                             New case/s (confirmed)  2946.0
# 26 2014-12-09                              Total suspected cases     0.0
# 27 2014-12-09                               Total probable cases     0.0
# 28 2014-12-09                              Total confirmed cases     0.0
# 29 2014-12-09  Total Number of Confirmed Cases \n of Sierra L...     0.0
# 30 2014-12-09  Total Number of Confirmed Cases \n of Guinean ...     0.0
# 31 2014-12-09  Cumulative confirmed, probable and suspected c...  7797.0
#
#                                         File  Country
# 0   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 1   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 2   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 3   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 4   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 5   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 6   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 7   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 8   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 9   ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 10  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 11  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 12  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 13  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 14  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 15  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 16  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 17  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 18  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 19  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 20  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 21  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 22  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 23  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 24  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 25  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 26  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 27  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 28  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# 29  ./Data/ebola/liberia_data/2014-06-16.csv  Liberia
# ..                                       ...      ...
# 2   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 3   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 4   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 5   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 6   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 7   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 8   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 9   ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 10  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 11  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 12  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 13  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 14  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 15  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 16  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 17  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 18  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 19  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 20  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 21  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 22  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 23  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 24  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 25  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 26  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 27  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 28  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 29  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 30  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
# 31  ./Data/ebola/liberia_data/2014-12-09.csv  Liberia
#
# [3152 rows x 5 columns]

# %%
print(liberia.Description.value_counts())

# check that 'Newly reported deaths' is in all files
ok_files = liberia[liberia.Description == 'Newly reported deaths'].File.unique()
liberia.query('File not in @ok_files').File.unique() # empty, they all have this field

# /!\ following fields have a duplicate
# Total death/s in confirmed cases                                    101
# Cumulative deaths among HCW                                         101
# Cumulative cases among HCW                                          101
# Total death/s in probable cases                                     101
# Total death/s in suspected cases                                    101

liberia.query('Description == "Total death/s in confirmed cases"').File.value_counts()
# ./Data/ebola/liberia_data/2014-10-04-v142.csv this file has double diff values
# does not affect us because it's only cumulative fields and we look at new death/case

death_desc = ['Newly reported deaths']
death_df = liberia.query('Description in @death_desc').copy()
death_df.Description = 'Death'

new_desc = ['New case/s (confirmed)', 'New Case/s (Probable)', 'New Case/s (Suspected)']
new_df = liberia.query('Description in @new_desc').copy()
# new_df.File.value_counts() # all 3 then all have everything
new_df.Description = 'New case'

liberia_filtered = pd.concat([death_df, new_df])
liberia_filtered.Totals = pd.to_numeric(liberia_filtered.Totals)
split_year_month(liberia_filtered)
liberia_filtered.groupby(['Country', 'Description', 'Year', 'Month']).sum()
# Out:
# Cumulative cases among HCW                                          101
# Total death/s in suspected cases                                    101
# Total death/s in confirmed cases                                    101
# Total death/s in probable cases                                     101
# Cumulative deaths among HCW                                         101
# Total suspected cases                                               100
# Contacts lost to follow-up                                          100
# Newly reported contacts                                             100
# New Case/s (Probable)                                               100
# New admissions                                                      100
# Total contacts listed                                               100
# Newly Reported deaths in HCW                                        100
# Contacts seen                                                       100
# Total probable cases                                                100
# Total discharges                                                    100
# Newly reported deaths                                               100
# Total confirmed cases                                               100
# Newly Reported Cases in HCW                                         100
# Currently under follow-up                                           100
# New case/s (confirmed)                                              100
# New Case/s (Suspected)                                              100
# Total specimens tested                                               99
# Specimens pending for testing                                        99
# Cumulative admission/isolation                                       99
# Specimens collected                                                  99
# Total no. currently in Treatment Units                               76
# Contacts who completed 21 day follow-up                              76
# Total death/s in confirmed, probable, suspected cases                76
# Total Number of Confirmed Cases of Sierra Leonean Nationality        76
# Total Number of Confirmed Cases of Guinean Nationality               76
# Case Fatality Rate (CFR) - Confirmed & Probable Cases                76
# Cumulative confirmed, probable and suspected cases                   33
# Total death/s in confirmed, \n probable, suspected cases             24
# Total Number of Confirmed Cases \n of Sierra Leonean Nationality     24
# Total no. currently in Treatment \n Units                            24
# Total Number of Confirmed Cases \n of Guinean Nationality            24
# Case Fatality Rate (CFR) - \n Confirmed & Probable Cases             24
# Contacts who completed 21 day \n follow-up                           24
# Cumulative (confirmed + probable + suspects)                         11
# Cumulative (confirmed + probable + suspected)                         2
# Total case/s (confirmed)                                              1
# Cumulative CFR                                                        1
# Total death/s in confirmed,  probable, suspected cases                1
# Total Case/s (Probable)                                               1
# Total Case/s (Suspected)                                              1
# Name: Description, dtype: int64
#                                  Totals
# Country Description Year Month
# Liberia Death       2014 6         14.0
#                          7         47.0
#                          8        209.0
#                          9        865.0
#                          10       701.0
#                          11       202.0
#                          12         0.0
#         New case    2014 6         40.0
#                          7         94.0
#                          8        335.0
#                          9       1532.0
#                          10      1139.0
#                          11       397.0
#                          12     46607.0

# %%
files = files_for_country('sl')
dfs = []
for f in files:
    df = pd.read_csv(f, parse_dates=['date'])
    df['File'] = f
    dfs.append(df)
sl = pd.concat(dfs)
sl = sl[['date', 'variable', 'National', 'File']]
sl.columns = ['Date', 'Description', 'Totals', 'File']
sl = sl.fillna(0)
sl['Country'] = 'Sierra Leone'
sl
# Out:
#          Date             Description     Totals  \
# 0  2014-08-12              population    6348350
# 1  2014-08-12             new_noncase          4
# 2  2014-08-12           new_suspected         10
# 3  2014-08-12            new_probable          1
# 4  2014-08-12           new_confirmed         11
# 5  2014-08-12             cum_noncase        657
# 6  2014-08-12           cum_suspected         46
# 7  2014-08-12            cum_probable         37
# 8  2014-08-12           cum_confirmed        717
# 9  2014-08-12         death_suspected          5
# 10 2014-08-12          death_probable         34
# 11 2014-08-12         death_confirmed        264
# 12 2014-08-12                     cfr       36.8
# 13 2014-08-12       etc_new_admission          0
# 14 2014-08-12  etc_currently_admitted          0
# 15 2014-08-12       etc_cum_admission          0
# 16 2014-08-12          etc_new_deaths          0
# 17 2014-08-12          etc_cum_deaths          0
# 18 2014-08-12      etc_new_discharges          0
# 19 2014-08-12      etc_cum_discharges          0
# 20 2014-08-12            cum_contacts       2838
# 21 2014-08-12  cum_completed_contacts        901
# 22 2014-08-12       contacts_followed       2255
# 23 2014-08-12            new_contacts        743
# 24 2014-08-12        contacts_healthy       1937
# 25 2014-08-12            contacts_ill         14
# 26 2014-08-12       contacts_not_seen        131
# 27 2014-08-12  new_completed_contacts         73
# 28 2014-08-12            percent_seen        87%
# 0  2014-08-13              population  6,348,350
# ..        ...                     ...        ...
# 7  2014-12-13            cum_probable         79
# 8  2014-12-13           cum_confirmed       6638
# 9  2014-12-13         death_suspected          0
# 10 2014-12-13          death_probable          0
# 11 2014-12-13         death_confirmed          0
# 12 2014-12-13                     cfr          0
# 13 2014-12-13       etc_new_admission          0
# 14 2014-12-13  etc_currently_admitted          0
# 15 2014-12-13       etc_cum_admission          0
# 16 2014-12-13          etc_new_deaths          0
# 17 2014-12-13          etc_cum_deaths          0
# 18 2014-12-13      etc_new_discharges          0
# 19 2014-12-13      etc_cum_discharges          0
# 20 2014-12-13            cum_contacts          0
# 21 2014-12-13  cum_completed_contacts          0
# 22 2014-12-13       contacts_followed          0
# 23 2014-12-13            new_contacts          0
# 24 2014-12-13        contacts_healthy          0
# 25 2014-12-13            contacts_ill          0
# 26 2014-12-13       contacts_not_seen          0
# 27 2014-12-13  new_completed_contacts          0
# 28 2014-12-13            percent_seen          0
# 29 2014-12-13       total_lab_samples          0
# 30 2014-12-13          repeat_samples          0
# 31 2014-12-13             new_samples          0
# 32 2014-12-13            new_positive          0
# 33 2014-12-13            new_negative          0
# 34 2014-12-13                 pending          0
# 35 2014-12-13         positive_corpse          0
# 36 2014-12-13         negative_corpse          0
#
#                                        File       Country
# 0   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 1   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 2   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 3   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 4   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 5   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 6   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 7   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 8   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 9   ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 10  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 11  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 12  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 13  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 14  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 15  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 16  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 17  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 18  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 19  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 20  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 21  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 22  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 23  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 24  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 25  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 26  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 27  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 28  ./Data/ebola/sl_data/2014-08-12-v77.csv  Sierra Leone
# 0   ./Data/ebola/sl_data/2014-08-13-v78.csv  Sierra Leone
# ..                                      ...           ...
# 7       ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 8       ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 9       ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 10      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 11      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 12      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 13      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 14      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 15      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 16      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 17      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 18      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 19      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 20      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 21      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 22      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 23      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 24      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 25      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 26      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 27      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 28      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 29      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 30      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 31      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 32      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 33      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 34      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 35      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
# 36      ./Data/ebola/sl_data/2014-12-13.csv  Sierra Leone
#
# [3262 rows x 5 columns]

# %%
print('Number of files for SL:', len(files_for_country('sl')))
sl.Description.value_counts()
# Out:
# Number of files for SL: 103
# death_probable            103
# death_suspected           103
# etc_new_discharges        103
# death_confirmed           103
# etc_cum_discharges        103
# new_probable              103
# contacts_ill              103
# contacts_healthy          103
# population                103
# etc_cum_admission         103
# contacts_followed         103
# etc_cum_deaths            103
# etc_currently_admitted    103
# etc_new_admission         103
# contacts_not_seen         103
# cum_confirmed             103
# new_completed_contacts    103
# cum_noncase               103
# new_noncase               103
# new_contacts              103
# new_suspected             103
# cum_completed_contacts    103
# etc_new_deaths            103
# cum_probable              103
# new_confirmed             103
# cfr                       103
# percent_seen              103
# cum_suspected             103
# cum_contacts              103
# positive_corpse            35
# negative_corpse            35
# pending                    35
# total_lab_samples          34
# new_negative               34
# new_samples                34
# new_positive               34
# repeat_samples             34
# Name: Description, dtype: int64

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
# Write your answer here

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
# Write your answer here
